# %% [markdown]
# 📌 Description:
# > * Write a Python program that prints the smallest value in a dictionary.
# > * If the dictionary is empty, print `None`.
# > * You may assume that the values are numeric.

# %% [markdown]
# 🔹 Expected Output:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# You may print "None" as a string or as the special value None.

# %% [markdown]
# ---
# #### Function
# ---

# %%
def smallest_in_dict(dict_: dict) -> int|None:
    if dict_:
        return min(dict_.values())
    return None

# %% [markdown]
# ---
# #### Tests
# ---

# %%
d = {"a": 4, "b": 3, "c": 7}
print(smallest_in_dict(d))
# Out:
# 3

# %%
d = {"a": 4, "b": 6}
print(smallest_in_dict(d))
# Out:
# 4

# %%
d = {"a": 4, "b": 4}
print(smallest_in_dict(d))
# Out:
# 4

# %%
d = {}
print(smallest_in_dict(d))
# Out:
# None
