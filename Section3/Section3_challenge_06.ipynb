# %% [markdown]
# 📌 Description:
# > * Write a Python program that reverses the individual words in the string s and changes their capitalization. Uppercase letters should be printed in lowercase and vice versa.
# > * Assume that the string only contains letters and spaces are used to separate words.

# %% [markdown]
# 🔹 Expected Output:
#
# ![image.png](attachment:image.png)

# %%
def str_reverse_case_swap(string: str) -> str:
    word_list = string.split()
    print(word_list)
    for idx, word in enumerate(word_list):
        word_list[idx] = word[::-1].swapcase()
    return " ".join(word_list)

# %%
print(str_reverse_case_swap("Hello World"))
print(str_reverse_case_swap("Python is Awesome"))
# Out:
# ['Hello', 'World']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\paulk\Projects\udemy\Udemy---Python-Challenges\Section3\Section3_challenge_06.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paulk/Projects/udemy/Udemy---Python-Challenges/Section3/Section3_challenge_06.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> print(str_reverse_case_swap("Hello World"))
#       <a href='vscode-notebook-cell:/c%3A/Users/paulk/Projects/udemy/Udemy---Python-Challenges/Section3/Section3_challenge_06.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> print(str_reverse_case_swap("Python is Awesome"))
#
# c:\Users\paulk\Projects\udemy\Udemy---Python-Challenges\Section3\Section3_challenge_06.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/paulk/Projects/udemy/Udemy---Python-Challenges/Section3/Section3_challenge_06.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> print(word_list)
#       <a href='vscode-notebook-cell:/c%3A/Users/paulk/Projects/udemy/Udemy---Python-Challenges/Section3/Section3_challenge_06.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> for idx, word in enumerate(word_list):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/paulk/Projects/udemy/Udemy---Python-Challenges/Section3/Section3_challenge_06.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     word[idx] = word[::-1].swapcase()
#       <a href='vscode-notebook-cell:/c%3A/Users/paulk/Projects/udemy/Udemy---Python-Challenges/Section3/Section3_challenge_06.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> return " ".join(word_list)
#
# TypeError: 'str' object does not support item assignment
