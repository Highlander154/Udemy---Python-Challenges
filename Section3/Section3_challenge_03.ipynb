# %% [markdown]
# 📌 Description:
# > * Write a Python program that prints a copy of the string s without any spaces.
# > * Words should be connected in the final string.
# > * If the string doesn't contain spaces, print it intact.

# %% [markdown]
# 🔹 Expected Output:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# #### Function
# ---

# %%
def remove_spaces(string: str) -> str:
    return string.replace(" ", "")

# %% [markdown]
# ---
# #### Tests
# ---

# %%
print(remove_spaces("Hello, World!"))
print(remove_spaces("Have a great day"))
print(remove_spaces("Python"))
print(remove_spaces("  no spaces allowed  "))
# Out:
# Hello,World!
# Haveagreatday
# Python
# nospacesallowed
