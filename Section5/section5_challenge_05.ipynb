# %% [markdown]
# 📌 Description:
# > * Write a Python program that prints the second smallest value in a list.
# > * If the list is empty or only has one element, print `None`.

# %% [markdown]
# 🔹 Expected Output:
# ![image.png](attachment:image.png)

# %% [markdown]
# 🔸 Hints:
# You might want to sort the list in ascending order.

# %% [markdown]
# ---
# #### Function
# ---

# %%
def nth_smallest(list_: list[int], n:int = 2) -> int|None:
    if len(list_) <= n-1:
        return None
    if n <= 0:
        return None
    return sorted(list_)[n-1]

# %% [markdown]
# ---
# #### Tests
# ---

# %%
print(nth_smallest([1,2,3,4]))
# Out:
# 2

# %%
print(nth_smallest([1,3]))
# Out:
# 3

# %%
print(nth_smallest([2]))
# Out:
# None

# %%
print(nth_smallest([]))
# Out:
# None
