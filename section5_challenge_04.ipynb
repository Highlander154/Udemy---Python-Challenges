# %% [markdown]
# 📌 Description:
# > * Write a Python program that prints the second largest value in a list.
# > * If the list is empty or only has one element, print None.

# %% [markdown]
# 🔹 Expected Output:
# ![image.png](attachment:image.png)

# %% [markdown]
# 🔸 Hints:
# You might want to sort the list in ascending order.

# %% [markdown]
# ---
# #### Function
# ---

# %%
def nth_largest(list_: list[int], n: int = 2) -> int|None:
    if len(list_) <= n-1:
        return None
    if n <= 0:
        return None
    return sorted(list_)[-n]

# %% [markdown]
# ---
# #### Tests
# ---

# %%
print(nth_largest([1,2,3,4]))
# Out:
# 3

# %%
print(nth_largest([1,2]))
# Out:
# 1

# %%
print(nth_largest([2]))
# Out:
# None

# %%
print(nth_largest([]))
# Out:
# None
