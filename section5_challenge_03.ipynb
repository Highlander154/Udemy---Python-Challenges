# %% [markdown]
# 📌 Description:
# > * Write a Python program that prints a list with the elements that listA and listB have in common.
# > * If they don't have any elements in common, print an empty list.
# > * The program should not assume that the lists have the same length.
# > * You may assume that each element will only appear once in each list.

# %% [markdown]
# 🔹 Expected Output:
# ![image.png](attachment:image.png)

# %%
def in_common(listA: list[int], listB: list[int]) -> list:
    l = [i for i in listA if i in listB]
    return l

# %%
print(in_common(listA=[1, 2, 3], listB=[1, 2, 3]))
# Out:
# [1, 2, 3]

# %%
print(in_common(listA=[4, 5, 6], listB=[1, 4, 5]))
# Out:
# [4, 5]

# %%
print(in_common(listA=[3, 4, 5], listB=[1, 2, 3]))
# Out:
# [3]

# %%
print(in_common(listA=[4, 5, 6], listB=[1, 2, 3]))
# Out:
# []
